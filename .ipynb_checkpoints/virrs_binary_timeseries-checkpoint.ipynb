# %%
import rasterio

# %%
with rasterio.open(r"C:\Users\Ankit\Datasets_Forest_fire\VIIRS_fire_time_stack1.tif") as src:
    profile= src.profile.copy()

# %%
src.profile
# Out:
# {'driver': 'GTiff', 'dtype': 'uint8', 'nodata': None, 'width': 17, 'height': 13, 'count': 17544, 'crs': CRS.from_wkt('GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]'), 'transform': Affine(0.25, 0.0, 77.0,
#        0.0, -0.25, 31.5), 'blockxsize': 17, 'blockysize': 1, 'tiled': False}

# %%
src.count
# Out:
# 17544

# %%
import rasterio

tif_path =r"C:\Users\Ankit\Datasets_Forest_fire\VIIRS_fire_time_stack1.tif"
with rasterio.open(tif_path) as src:
    print("Number of bands:", src.count)

    # Check global metadata
    print("\nGlobal metadata:")
    print(src.tags())

    # Check per-band metadata
    for i in range(1, src.count + 1):
        print(f"\nBand {i} metadata:")
        print(src.tags(i))
        print("Description:", src.descriptions[i-1])
# Out:
# Number of bands: 17544
#
# Global metadata:
# {'description': 'Binary fire mask (0/1)', 'variable': 'fire_label', 'AREA_OR_POINT': 'Area'}
#
# Band 1 metadata:
# {}
# Description: None
#
# Band 2 metadata:
# {}
# Description: None
#
# Band 3 metadata:
# {}
# Description: None
#
# Band 4 metadata:
# {}
# Description: None
#
# Band 5 metadata:
# {}
# Description: None
#
# Band 6 metadata:
# {}
# Description: None
#
# Band 7 metadata:
# {}
# Description: None
#
# Band 8 metadata:
# {}
# Description: None
#
# Band 9 metadata:
# {}
# Description: None
#
# Band 10 metadata:
# {}
# Description: None
#
# Band 11 metadata:
# {}
# Description: None
#
# Band 12 metadata:
# {}
# Description: None
#
# Band 13 metadata:
# {}
# Description: None
#
# Band 14 metadata:
# {}
# Description: None
#
# Band 15 metadata:
# {}
# Description: None
#
# Band 16 metadata:
# {}
# Description: None
#
# Band 17 metadata:
# {}
# Description: None
#
# Band 18 metadata:
# {}
# Description: None
#
# Band 19 metadata:
# ...
